# %%
from langchain_community.document_loaders import PyPDFLoader, DirectoryLoader, Docx2txtLoader

# %%
pdf_data_path = "../data/word"

# %%
loader = DirectoryLoader(pdf_data_path, glob="*.docx", loader_cls = Docx2txtLoader)
documents = loader.load()

# %%
documents
# Out:
# [Document(page_content='Hỏi: Em nên chọn ngành nào?\n\nNên chọn theo sự yêu thích, khả năng của mình?\n\nEm có thích lập trình? Em có thích mày mò các thiết bị vật lý (cầm nắm, sờ mó)? \n\nEm có học toán, lý giỏi? Em đã biết lập trình?\n\nChọn Điện tử Viễn thông ngay và luôn\n\n\n\nHỏi: Điện tử Viễn thông có học lập trình không?\n\nĐTVT học nhiều lập trình, thuật toán; \n\nĐTVT không chỉ lập trình cho máy tính cá nhân, mà lập trình cho các máy tính nhúng trong các thiết bị điện tử (điện thoại di động, đầu phát wifi, tivi, tủ lạnh, ô tô, máy bay, thẻ ngân hàng, đồng hồ thông minh, tên lửa…)\n\nHỏi: Em chưa biết lập trình tí gì?\n\nYên tâm vào ĐTVT sẽ được dạy lập trình rất bài bản.\n\n\n\n\n\nQ: Điện tử Viễn thông làm cái gì?\n\nThiết kế mạch điện tử, máy tính (kiến trúc sư)\n\nChế tạo mạch điện tử, máy tính (xây dựng)\n\nLập trình mạch điện tử, máy tính nhúng, ứng dụng.\n\nTích hợp, tối ưu mạng máy tính, mạng viễn thông, mạng 4G, 5G, IoT\n\nNghiên cứu phát triển thiết bị y tế, hàng không, giao thông, quân sự, dân sự, viễn thông, …\n\n\n\n\n\nHỏi: Tỉ lệ có việc sau khi tốt nghiệp? Cơ hội việc làm?\n\n95% có việc sau 6 tháng; 5% đi du học và làm việc tại nước ngoài.\n\nĐiện tử Viễn thông: ngành hiệu quả, nhiều việc làm, ít cạnh tranh.\n\n\n\nHỏi: Điện tử Viễn thông ra làm ở đâu? \n\nCác công ty nghiên cứu, phát triển, vận hành thiết bị điện tử (dân dụng, quân sự, y tế, giao thông, hàng không, ô tô), các start-up\n\nHỏi: Mức lương khoảng bao nhiêu?\n\nMức lương khoảng 10-20 triệu.\n\nKĩ sư nghiên cứu phát triển: 20-40 triệu. (VHT trả tới 2000 USD)\n\nKĩ sư tại nước ngoài (Nhật Bản, Châu Âu, Mỹ): 50-100 triệu/1 tháng.\n\n\n\nHỏi: Ngành ET1 học bằng tiếng gì?\n\nTiếng Việt. \n\nHỏi: Ngành ETE4, ETE5, ETE16 học bằng tiếng gì?\n\nTiếng Anh, có chương trình HUST-start để bồi dưỡng tiếng Anh ở năm 1.\n\nHỏi: ngành ET-E9 học bằng tiếng gì?\n\nTiếng Việt. Tiếng Nhật là môn ngoại ngữ tăng cơ hội làm việc tại Nhật. \n\nHỏi: ngành ET-LUH học bằng tiếng gì?\n\nTiếng Việt. Tiếng Đức là môn ngoại ngữ tăng cơ hội đi học tiếp ở Đức\n\nHỏi: ngành ET-E16 mới mở? Ngành HOT – Trí tuệ nhân tạo trong xử lý đa phương tiện\n\nHỏi: Ngành ET2 là gì? - Ngành mới mở về khoa học sự sống - Kỹ thuật Y sinh\n\nET1, ET1x: Chương trình chuẩn Kỹ thuật Điện tử Viễn thông \n\nChỉ tiêu: 480\n\nHọc phí: 22-28 triệu/1 năm\n\nĐiểm trúng tuyển: 24.80 (2019), 27.30 (2020)\n\nET-E4, ET-E4x: Chương trình tiên tiến Kỹ thuật Điện tử Viễn thông\n\nChỉ tiêu: 60\n\nHọc phí: 40-45 triệu/1 năm\n\nĐiểm trúng tuyển: 24.60 (2019), 27.15 (2020) \n\nET-E5, ET-E5x: Chương trình tiên tiến Kỹ thuật Y sinh\n\nChỉ tiêu: 40\n\nHọc phí: 40-45 triệu/1 năm\n\nĐiểm trúng tuyển: 24.10 (2019), 26,50 (2020)\n\nET-E9: Chương trình tiên tiến Hệ thống nhúng thông minh và IoT\n\nChỉ tiêu: 60\n\nHọc phí: 40-45 triệu/1 năm\n\nĐiểm trúng tuyển: 24.95 (2019), 27.51 (2020)\n\n\n\nET-LUH: Chương trình liên kết quốc tế Điện tử Viễn thông\n\nChỉ tiêu: 40\n\nHọc phí: 50-60 triệu/1 năm\n\nĐiểm trúng tuyển: 24.95 (2019), 23.85 (2020)\n\nET-E2: Chương trình kỹ thuật Y sinh\n\nChỉ tiêu: 60\n\nHọc phí:22-28 triệu/1 năm\n\nChương trình mới mở 2022\n\nEm tìm thêm thông tin ở đâu: \n\nFlyer\n\nwww.facebook.com/set2010\n\nset.hust.edu.vn/sinh-vien-tuong-lai\n\nHot line: 0963122389 (Thầy Minh), \n\nET-E16: Chương trình tiên tiến Truyền thông số và Kỹ thuật Đa phương tiện\n\nChỉ tiêu: 60\n\nHọc phí:40-45 triệu/1 năm\n\nChương trình mới mở 2020', metadata={'source': '../data/word/Flyer Hỏi đáp - 2021.docx'}),
#  Document(page_content='Hỏi: Em nên chọn ngành nào?\n\nNên chọn theo sự yêu thích, khả năng của mình?\n\nEm có thích lập trình? Em có thích mày mò các thiết bị vật lý (cầm nắm, sờ mó)? \n\nEm có học toán, lý giỏi? Em đã biết lập trình?\n\nChọn Điện tử Viễn thông ngay và luôn\n\n\n\nHỏi: Điện tử Viễn thông có học lập trình không?\n\nĐTVT học nhiều lập trình, thuật toán; \n\nĐTVT không chỉ lập trình cho máy tính cá nhân, mà lập trình cho các máy tính nhúng trong các thiết bị điện tử (điện thoại di động, đầu phát wifi, tivi, tủ lạnh, ô tô, máy bay, thẻ ngân hàng, đồng hồ thông minh, tên lửa…)\n\nHỏi: Em chưa biết lập trình tí gì?\n\nYên tâm vào ĐTVT sẽ được dạy lập trình rất bài bản.\n\n\n\n\n\nQ: Điện tử Viễn thông làm cái gì?\n\nThiết kế mạch điện tử, máy tính (kiến trúc sư)\n\nChế tạo mạch điện tử, máy tính (xây dựng)\n\nLập trình mạch điện tử, máy tính nhúng, ứng dụng.\n\nTích hợp, tối ưu mạng máy tính, mạng viễn thông, mạng 4G, 5G, IoT\n\nNghiên cứu phát triển thiết bị y tế, hàng không, giao thông, quân sự, dân sự, viễn thông, …\n\n\n\n\n\nHỏi: Tỉ lệ có việc sau khi tốt nghiệp? Cơ hội việc làm?\n\n95% có việc sau 6 tháng; 5% đi du học và làm việc tại nước ngoài.\n\nĐiện tử Viễn thông: ngành hiệu quả, nhiều việc làm, ít cạnh tranh.\n\n\n\nHỏi: Điện tử Viễn thông ra làm ở đâu? \n\nCác công ty nghiên cứu, phát triển, vận hành thiết bị điện tử (dân dụng, quân sự, y tế, giao thông, hàng không, ô tô), các start-up\n\nHỏi: Mức lương khoảng bao nhiêu?\n\nMức lương khoảng 10-20 triệu.\n\nKĩ sư nghiên cứu phát triển: 20-40 triệu. (VHT trả tới 2000 USD)\n\nKĩ sư tại nước ngoài (Nhật Bản, Châu Âu, Mỹ): 50-100 triệu/1 tháng.\n\n\n\nHỏi: Ngành ET1 học bằng tiếng gì?\n\nTiếng Việt. \n\nHỏi: Ngành ETE4, ETE5, ETE16 học bằng tiếng gì?\n\nTiếng Anh, có chương trình HUST-start để bồi dưỡng tiếng Anh ở năm 1.\n\nHỏi: ngành ET-E9 học bằng tiếng gì?\n\nTiếng Việt. Tiếng Nhật là môn ngoại ngữ tăng cơ hội làm việc tại Nhật. \n\nHỏi: ngành ET-LUH học bằng tiếng gì?\n\nTiếng Việt. Tiếng Đức là môn ngoại ngữ tăng cơ hội đi học tiếp ở Đức\n\nHỏi: ngành ET-E16 mới mở? Ngành HOT – Trí tuệ nhân tạo trong xử lý đa phương tiện\n\nHỏi: Ngành ET2 là gì? - Ngành mới mở về khoa học sự sống - Kỹ thuật Y sinh\n\nET1, ET1x: Chương trình chuẩn Kỹ thuật Điện tử Viễn thông \n\nChỉ tiêu: 480\n\nHọc phí: 22-28 triệu/1 năm\n\nĐiểm trúng tuyển: 24.80 (2019), 27.30 (2020)\n\nET-E4, ET-E4x: Chương trình tiên tiến Kỹ thuật Điện tử Viễn thông\n\nChỉ tiêu: 60\n\nHọc phí: 40-45 triệu/1 năm\n\nĐiểm trúng tuyển: 24.60 (2019), 27.15 (2020) \n\nET-E5, ET-E5x: Chương trình tiên tiến Kỹ thuật Y sinh\n\nChỉ tiêu: 40\n\nHọc phí: 40-45 triệu/1 năm\n\nĐiểm trúng tuyển: 24.10 (2019), 26,50 (2020)\n\nET-E9: Chương trình tiên tiến Hệ thống nhúng thông minh và IoT\n\nChỉ tiêu: 60\n\nHọc phí: 40-45 triệu/1 năm\n\nĐiểm trúng tuyển: 24.95 (2019), 27.51 (2020)\n\n\n\nET-LUH: Chương trình liên kết quốc tế Điện tử Viễn thông\n\nChỉ tiêu: 40\n\nHọc phí: 50-60 triệu/1 năm\n\nĐiểm trúng tuyển: 24.95 (2019), 23.85 (2020)\n\nET-E2: Chương trình kỹ thuật Y sinh\n\nChỉ tiêu: 60\n\nHọc phí:22-28 triệu/1 năm\n\nChương trình mới mở 2022\n\nEm tìm thêm thông tin ở đâu: \n\nFlyer\n\nwww.facebook.com/set2010\n\nset.hust.edu.vn/sinh-vien-tuong-lai\n\nHot line: 0963122389 (Thầy Minh), \n\nET-E16: Chương trình tiên tiến Truyền thông số và Kỹ thuật Đa phương tiện\n\nChỉ tiêu: 60\n\nHọc phí:40-45 triệu/1 năm\n\nChương trình mới mở 2020', metadata={'source': '../data/word/Flyer Hỏi đáp - 2021 (1).docx'}),
#  Document(page_content='ETE9\n\n1) Học gì?\n\n- Mạch điện tử, thiết kế mạch, thiết kế vi mạch\n\n- Cấu trúc máy tính (nhúng) - là máy tính trong điện thoại, trong ô tô, trong thiết bị điện tử gia dụng, trong thẻ ngân hàng\n\n- Lập trình máy tính nhúng: ngôn ngữ lập trình C, hệ điều hành trên máy tính nhúng, điều khiển các cảm biến, động cơ trong các thiết bị (điều khiển phần cứng)\n\n- Kết nối IoT - Kết nối 4G, 5G, Bluetooth, WIFI, ...\n\n- Lập trình truyền dữ liệu từ máy tính nhúng lên máy chủ: Lập trình Java\n\n- Lập trình ứng dụng học máy và trí tuệ nhân tạo để phân tích dữ liệu: Lập trình python\n\n- Tiếng Nhật là ngoại ngữ\n\n2) Làm ở đâu:\n\n- Viettel High Tech, VNPT Tech, Samsung, Toshiba, Panasonic, LG Electronics, Nisan, FPT Software, FPT Japan, Bosch, Lumi, BKAV, HCL, các công ty tại Nhật, McNex, Patron, ... (nhiều quá biết không hết)\n\n3) Lương khởi điểm: 13-15 triệu. Đi Nhật thì tầm 50 triệu - cần N3, N2 và qua phỏng vấn của công ty thì được tuyển từ hết năm 3 (1 tháng)\n\nET1\n\nHọc như nào là sao? Khó như bao ngành khác, nhiều bài tập, nhiều dự án.\n\nHọc gì? - Mạch điện tử, vi mạch (con chip đen đen bé tí trên mạch điện tử) cấu trúc máy tính (nhúng - là các máy tính được đưa vào trong ô tô, thiết bị điện tử - tivi, tủ\xa0lạnh, camera, thiết bị viễn thông - trạm phát 4G, 5G, wifi, ... ), lập trình (tất tần tật các loại luôn - từ phần cứng, đến web, app, cơ sở dữ liệu, máy chủ), hệ thống thông tin di động (4G, 5G), mạng máy tính, thiết bị Y sinh, hàng không vũ trụ.\n\nLàm ở đâu: Các công ty thiết kế chip (Infineon, Viettel, FPT Semi, Synopsys, Qorvo, Dolphin, HCL, CoAsia, Renesas, Intel), các công ty làm mạch điện tử, làm máy tính nhúng, làm điện thoại (Bosch, FPT Software, Panasonics, LGE, Samsung, Toshiba, Nisan, FPT Japan, VNPT Technology, Viettel High Tech, Meiko, McNex, Patron Vina), Các công ty di động (Vinaphone, Mobifone, Viettel), Các bệnh viện, Các sân bay, Các công ty làm phân tích dữ liệu, AI/ML (VinBigData, VinAI, Viettel, các ngân hàng, VNPT Media, VNPT IT), Các công ty phần mềm (Avepoint, Savycom, FPT Software, VNPT, Viettel, cái này thì nhiều vô số kể, ...)\n\nMức lương thế nào: mới ra trường 13-15 triệu/1 tháng.', metadata={'source': '../data/word/Review ngànhh (1).docx'}),
#  Document(page_content='ETE9\n\n1) Học gì?\n\n- Mạch điện tử, thiết kế mạch, thiết kế vi mạch\n\n- Cấu trúc máy tính (nhúng) - là máy tính trong điện thoại, trong ô tô, trong thiết bị điện tử gia dụng, trong thẻ ngân hàng\n\n- Lập trình máy tính nhúng: ngôn ngữ lập trình C, hệ điều hành trên máy tính nhúng, điều khiển các cảm biến, động cơ trong các thiết bị (điều khiển phần cứng)\n\n- Kết nối IoT - Kết nối 4G, 5G, Bluetooth, WIFI, ...\n\n- Lập trình truyền dữ liệu từ máy tính nhúng lên máy chủ: Lập trình Java\n\n- Lập trình ứng dụng học máy và trí tuệ nhân tạo để phân tích dữ liệu: Lập trình python\n\n- Tiếng Nhật là ngoại ngữ\n\n2) Làm ở đâu:\n\n- Viettel High Tech, VNPT Tech, Samsung, Toshiba, Panasonic, LG Electronics, Nisan, FPT Software, FPT Japan, Bosch, Lumi, BKAV, HCL, các công ty tại Nhật, McNex, Patron, ... (nhiều quá biết không hết)\n\n3) Lương khởi điểm: 13-15 triệu. Đi Nhật thì tầm 50 triệu - cần N3, N2 và qua phỏng vấn của công ty thì được tuyển từ hết năm 3 (1 tháng)\n\nET1\n\nHọc như nào là sao? Khó như bao ngành khác, nhiều bài tập, nhiều dự án.\n\nHọc gì? - Mạch điện tử, vi mạch (con chip đen đen bé tí trên mạch điện tử) cấu trúc máy tính (nhúng - là các máy tính được đưa vào trong ô tô, thiết bị điện tử - tivi, tủ\xa0lạnh, camera, thiết bị viễn thông - trạm phát 4G, 5G, wifi, ... ), lập trình (tất tần tật các loại luôn - từ phần cứng, đến web, app, cơ sở dữ liệu, máy chủ), hệ thống thông tin di động (4G, 5G), mạng máy tính, thiết bị Y sinh, hàng không vũ trụ.\n\nLàm ở đâu: Các công ty thiết kế chip (Infineon, Viettel, FPT Semi, Synopsys, Qorvo, Dolphin, HCL, CoAsia, Renesas, Intel), các công ty làm mạch điện tử, làm máy tính nhúng, làm điện thoại (Bosch, FPT Software, Panasonics, LGE, Samsung, Toshiba, Nisan, FPT Japan, VNPT Technology, Viettel High Tech, Meiko, McNex, Patron Vina), Các công ty di động (Vinaphone, Mobifone, Viettel), Các bệnh viện, Các sân bay, Các công ty làm phân tích dữ liệu, AI/ML (VinBigData, VinAI, Viettel, các ngân hàng, VNPT Media, VNPT IT), Các công ty phần mềm (Avepoint, Savycom, FPT Software, VNPT, Viettel, cái này thì nhiều vô số kể, ...)\n\nMức lương thế nào: mới ra trường 13-15 triệu/1 tháng.', metadata={'source': '../data/word/Review ngànhh.docx'}),
#  Document(page_content='Hỏi: Em nên chọn ngành nào?\n\nNên chọn theo sự yêu thích, khả năng của mình?\n\nEm có thích lập trình? Em có thích mày mò các thiết bị vật lý (cầm nắm, sờ mó)? \n\nEm có học toán, lý giỏi? Em đã biết lập trình?\n\nChọn Điện tử Viễn thông ngay và luôn\n\n\n\nHỏi: Điện tử Viễn thông có học lập trình không?\n\nĐTVT học nhiều lập trình, thuật toán; \n\nĐTVT không chỉ lập trình cho máy tính cá nhân, mà lập trình cho các máy tính nhúng trong các thiết bị điện tử (điện thoại di động, đầu phát wifi, tivi, tủ lạnh, ô tô, máy bay, thẻ ngân hàng, đồng hồ thông minh, tên lửa…)\n\nHỏi: Em chưa biết lập trình tí gì?\n\nYên tâm vào ĐTVT sẽ được dạy lập trình rất bài bản.\n\n\n\n\n\nQ: Điện tử Viễn thông làm cái gì?\n\nThiết kế mạch điện tử, máy tính (kiến trúc sư)\n\nChế tạo mạch điện tử, máy tính (xây dựng)\n\nLập trình mạch điện tử, máy tính nhúng, ứng dụng.\n\nTích hợp, tối ưu mạng máy tính, mạng viễn thông, mạng 4G, 5G, IoT\n\nNghiên cứu phát triển thiết bị y tế, hàng không, giao thông, quân sự, dân sự, viễn thông, …\n\n\n\n\n\nHỏi: Tỉ lệ có việc sau khi tốt nghiệp? Cơ hội việc làm?\n\n95% có việc sau 6 tháng; 5% đi du học và làm việc tại nước ngoài.\n\nĐiện tử Viễn thông: ngành hiệu quả, nhiều việc làm, ít cạnh tranh.\n\n\n\nHỏi: Điện tử Viễn thông ra làm ở đâu? \n\nCác công ty nghiên cứu, phát triển, vận hành thiết bị điện tử (dân dụng, quân sự, y tế, giao thông, hàng không, ô tô), các start-up\n\nHỏi: Mức lương khoảng bao nhiêu?\n\nMức lương khoảng 10-20 triệu.\n\nKĩ sư nghiên cứu phát triển: 20-40 triệu. (VHT trả tới 2000 USD)\n\nKĩ sư tại nước ngoài (Nhật Bản, Châu Âu, Mỹ): 50-100 triệu/1 tháng.\n\n\n\nHỏi: Ngành ET1 học bằng tiếng gì?\n\nTiếng Việt. \n\nHỏi: Ngành ETE4, ETE5, ETE16 học bằng tiếng gì?\n\nTiếng Anh, có chương trình HUST-start để bồi dưỡng tiếng Anh ở năm 1.\n\nHỏi: ngành ET-E9 học bằng tiếng gì?\n\nTiếng Việt. Tiếng Nhật là môn ngoại ngữ tăng cơ hội làm việc tại Nhật. \n\nHỏi: ngành ET-LUH học bằng tiếng gì?\n\nTiếng Việt. Tiếng Đức là môn ngoại ngữ tăng cơ hội đi học tiếp ở Đức\n\nHỏi: ngành ET-E16 mới mở? Ngành HOT – Trí tuệ nhân tạo trong xử lý đa phương tiện\n\nHỏi: Ngành ET2 là gì? - Ngành mới mở về khoa học sự sống - Kỹ thuật Y sinh\n\nET1, ET1x: Chương trình chuẩn Kỹ thuật Điện tử Viễn thông \n\nChỉ tiêu: 480\n\nHọc phí: 22-28 triệu/1 năm\n\nĐiểm trúng tuyển: 24.80 (2019), 27.30 (2020)\n\nET-E4, ET-E4x: Chương trình tiên tiến Kỹ thuật Điện tử Viễn thông\n\nChỉ tiêu: 60\n\nHọc phí: 40-45 triệu/1 năm\n\nĐiểm trúng tuyển: 24.60 (2019), 27.15 (2020) \n\nET-E5, ET-E5x: Chương trình tiên tiến Kỹ thuật Y sinh\n\nChỉ tiêu: 40\n\nHọc phí: 40-45 triệu/1 năm\n\nĐiểm trúng tuyển: 24.10 (2019), 26,50 (2020)\n\nET-E9: Chương trình tiên tiến Hệ thống nhúng thông minh và IoT\n\nChỉ tiêu: 60\n\nHọc phí: 40-45 triệu/1 năm\n\nĐiểm trúng tuyển: 24.95 (2019), 27.51 (2020)\n\n\n\nET-LUH: Chương trình liên kết quốc tế Điện tử Viễn thông\n\nChỉ tiêu: 40\n\nHọc phí: 50-60 triệu/1 năm\n\nĐiểm trúng tuyển: 24.95 (2019), 23.85 (2020)\n\nET-E2: Chương trình kỹ thuật Y sinh\n\nChỉ tiêu: 60\n\nHọc phí:22-28 triệu/1 năm\n\nChương trình mới mở 2022\n\nEm tìm thêm thông tin ở đâu: \n\nFlyer\n\nwww.facebook.com/set2010\n\nset.hust.edu.vn/sinh-vien-tuong-lai\n\nHot line: 0963122389 (Thầy Minh), \n\nET-E16: Chương trình tiên tiến Truyền thông số và Kỹ thuật Đa phương tiện\n\nChỉ tiêu: 60\n\nHọc phí:40-45 triệu/1 năm\n\nChương trình mới mở 2020', metadata={'source': '../data/word/Flyer Hỏi đáp - 2021 (2).docx'}),
#  Document(page_content='Câu hỏi 1:Em đang phân vân có nên lựa chọn ngành Công nghệ Kỹ thuật Điện tử Viễn thông hay không vì sợ ra trường khó xin việc. Thầy, Cô có thể tư vấn giúp em được không ạ?\n\n\n\nTrả lời:\n\n\n\nChào em!\n\n\n\nHiện nay tổng số nhân lực của nhóm ngành Công nghệ kỹ thuật Điện tử Viễn thông, công nghệ thông tin là khoảng 556 ngàn người và dự báo đến năm 2020 sẽ cần lượng nhân lực khoảng 758 ngàn người. Theo trung tâm dự báo nhu cầu nhân lực và thông tin thị trường TP Hồ Chí Minh, nhu cầu nhân sự nhóm ngành nghề này trong giai đoạn 2020-2025 vẫn có nhu cầu tuyển dụng rất lớn, có thể lên đến 16.200 người/năm. Trong nhiều năm tới nhu cầu nhân lực ngành này còn cao hơn rất nhiều khi các tập đoàn sản xuất thiết bị điện tử hàng đầu thế giới tới Việt Nam. Nên học ngành này em không cần lo lắng về vấn đề khó xin việc.\n\n\n\nChúc em may mắn!\n\n\n\n \n\n\n\nCâu hỏi 2: Thầy Cô cho em hỏi học ngành Công nghệ kỹ thuật Điện tử Viễn thông có dễ xin việc không? Thu nhập sau khi tốt nghiệp ngành này có cao không?\n\n\n\nTrả lời:\n\n\n\nChào em!\n\n\n\nMục tiêu đào tạo của ngành Công nghệ Kỹ thuật Điện tử Viễn thônglà tạo cơ hội việc làm cho sinh viên không chỉ ở trong nước mà còn ở quy mô toàn cầu. Vì ngành Công nghệ kỹ thuật Điện tử Viễn thông đang là ngành có tốc độ tăng trưởng rất cao, cơ hội nghề nghiệp và thăng tiến là không giới hạn.\n\nCâu hỏi 3:Chào Thầy Cô, em đang phân vân lựa chọn giữa ngành Công nghệ kỹ thuật Điện tử viễn thông với ngành Công nghệ kỹ thuật Điều khiển và Tự động hóa. Xin cho em biết sự khác nhau giữa hai ngành để có lựa chọn đúng đắn nhất?\n\n\n\nTrả lời:\n\n\n\nChào em!\n\n\n\nHai ngành này có sự giao thoa với nhau, ngành Công nghệ kỹ thuật Điều khiển và tự động hóa lĩnh vực chính đào tạo là điện tự động hóa, điện công nghiệp và khoa học máy tính. Ngành Công nghệ kỹ thuật Điện tử Viễn thông lĩnh vực chính đào tạo là điện tử công nghiệp, điện tử tin học, điện tử y sinh, điện tử hàng không, điện tử điện lạnh, khoa học máy tính và công nghệ truyền thông tin.\n\nCâu hỏi 4:Chào Thầy Cô, em đang phân vân lựa chọn giữa ngành Công nghệ kỹ thuật Điện tử viễn thông với ngành Công nghệ thông tin. Xin cho em biết sự khác nhau giữa hai ngành để có lựa chọn đúng đắn nhất?\n\n\n\nTrả lời:\n\n\n\nChào em!\n\n\n\nHai ngành này có sự giao thoa với nhau, ngành Công nghệ thông tin lĩnh vực đào tạo thiên hướng mạnh về phần mềm và giải pháp như hệ thống thông tin, kỹ thuật phần mềm, mạng máy tính và mạng truyền thông. Còn ngành Công nghệ kỹ thuật Điện tử viễn thông thiên hướng mạnh về phần cứng để chế tạo và can thiệp trực tiếp tới chất lượng của hệ thống. Lĩnh vực chính đào tạo của ngành này là điện tử công nghiệp, điện tử tin học, điện tử y sinh, điện tử hàng không, điện tử điện lạnh, khoa học máy tính và kỹ thuật truyền thông tin.\n\nCâu hỏi 5:Em muốn làm việc tại các công ty liên quan đến cung cấp dịch vụ, sản xuất hoặc thiết kế giải pháp cho hệ thống viễn thông, Internet. Vậy em nên lựa chọn ngành nào cho phù hợp?\n\n\n\nTrả lời:\n\n\n\nChào em!\n\n\n\nCác công ty này có những vị trí công việc liên quan đến cả hai ngành Công nghệ Kỹ thuật Điện tử Viễn thông, Công nghệ Kỹ thuật máy tính và Công nghệ Thông tin. Trong đó, ngành công nghệ thông tin tập trung vào việc xây dựng các phần mềm ứng dụng, còn ngành Công nghệ Kỹ thuật Điện tử viễn thông tập trung về nghiên cứu phát triển các giải pháp kỹ thuật phần cứng, ngành Công nghệ Kỹ thuật máy tính thì xây dựng xây dựng cả phần mềm và phát triển các giải pháp về phần cứng. Tùy vào vị trí công việc cụ thể em hãy tự đưa ra sự lựa chọn ngành phù hợp.\n\nCâu hỏi 6:Em thấy các thông tin như: mạng 3G, 4G hay 5G- kẻ hủy diệt mạng wifi trong tương lai nghe rất hấp dẫn. Thầy, Cô cho em hỏi những thông tin này liên quan đến ngành học nào?\n\n\n\nTrả lời:\n\n\n\nChào em!\n\n\n\nMạng 3G, 4G hay 5G là khái niệm về các thế hệ mạng di động của công nghệ truyền thông di động thuộc kiến thức ngành Công nghệ Kỹ thuật Điện tử Viễn thông. Học ngành này em sẽ được đào tạo và tiếp cận  ...
